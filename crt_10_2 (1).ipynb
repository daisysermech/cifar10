# %%
import tensorflow.keras as ker
from tensorflow.keras.models import Sequential
from keras.utils import np_utils
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import LearningRateScheduler
import numpy as np
import matplotlib.pyplot as plt 

def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    elif epoch > 100:
        lrate = 0.0003        
    return lrate

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

model.summary()

#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)

#training
batch_size = 64

opt_rms = optimizers.RMSprop(learning_rate=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=90,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])

plt.plot(history.history['accuracy'],label = 'accuracy')
plt.plot(history.history['val_accuracy'],label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.ylim([0.4,1])
plt.legend(loc = 'lower right')

#save to disk
model.save('model')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/90
# 781/781 [==============================] - 66s 68ms/step - loss: 1.8844 - accuracy: 0.4276 - val_loss: 1.2238 - val_accuracy: 0.6159 - lr: 0.0010
# Epoch 2/90
# 781/781 [==============================] - 53s 68ms/step - loss: 1.2426 - accuracy: 0.5929 - val_loss: 1.3127 - val_accuracy: 0.6261 - lr: 0.0010
# Epoch 3/90
# 781/781 [==============================] - 53s 68ms/step - loss: 1.0645 - accuracy: 0.6558 - val_loss: 0.9440 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 4/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.9713 - accuracy: 0.6921 - val_loss: 0.9975 - val_accuracy: 0.7082 - lr: 0.0010
# Epoch 5/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.9038 - accuracy: 0.7169 - val_loss: 0.8101 - val_accuracy: 0.7560 - lr: 0.0010
# Epoch 6/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8505 - accuracy: 0.7377 - val_loss: 0.8821 - val_accuracy: 0.7494 - lr: 0.0010
# Epoch 7/90
# 781/781 [==============================] - 54s 69ms/step - loss: 0.8206 - accuracy: 0.7501 - val_loss: 0.7661 - val_accuracy: 0.7860 - lr: 0.0010
# Epoch 8/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.7970 - accuracy: 0.7597 - val_loss: 0.7024 - val_accuracy: 0.7999 - lr: 0.0010
# Epoch 9/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.7761 - accuracy: 0.7692 - val_loss: 0.8011 - val_accuracy: 0.7738 - lr: 0.0010
# Epoch 10/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.7576 - accuracy: 0.7784 - val_loss: 0.7175 - val_accuracy: 0.7988 - lr: 0.0010
# Epoch 11/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.7333 - accuracy: 0.7859 - val_loss: 0.7105 - val_accuracy: 0.8002 - lr: 0.0010
# Epoch 12/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.7288 - accuracy: 0.7909 - val_loss: 0.6861 - val_accuracy: 0.8129 - lr: 0.0010
# Epoch 13/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.7144 - accuracy: 0.7945 - val_loss: 0.7456 - val_accuracy: 0.7948 - lr: 0.0010
# Epoch 14/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.7050 - accuracy: 0.7998 - val_loss: 0.6831 - val_accuracy: 0.8157 - lr: 0.0010
# Epoch 15/90
# 781/781 [==============================] - 55s 71ms/step - loss: 0.6943 - accuracy: 0.8040 - val_loss: 0.7185 - val_accuracy: 0.8020 - lr: 0.0010
# Epoch 16/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6895 - accuracy: 0.8073 - val_loss: 0.6940 - val_accuracy: 0.8141 - lr: 0.0010
# Epoch 17/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6789 - accuracy: 0.8106 - val_loss: 0.6649 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 18/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6742 - accuracy: 0.8121 - val_loss: 0.6619 - val_accuracy: 0.8257 - lr: 0.0010
# Epoch 19/90
# 781/781 [==============================] - 55s 71ms/step - loss: 0.6722 - accuracy: 0.8142 - val_loss: 0.6658 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 20/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6653 - accuracy: 0.8177 - val_loss: 0.6544 - val_accuracy: 0.8318 - lr: 0.0010
# Epoch 21/90
# 781/781 [==============================] - 55s 71ms/step - loss: 0.6604 - accuracy: 0.8199 - val_loss: 0.6609 - val_accuracy: 0.8236 - lr: 0.0010
# Epoch 22/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6590 - accuracy: 0.8209 - val_loss: 0.6824 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 23/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6561 - accuracy: 0.8221 - val_loss: 0.6198 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 24/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6503 - accuracy: 0.8242 - val_loss: 0.6085 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 25/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6504 - accuracy: 0.8240 - val_loss: 0.5749 - val_accuracy: 0.8530 - lr: 0.0010
# Epoch 26/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6414 - accuracy: 0.8275 - val_loss: 0.6674 - val_accuracy: 0.8308 - lr: 0.0010
# Epoch 27/90
# 781/781 [==============================] - 55s 70ms/step - loss: 0.6392 - accuracy: 0.8286 - val_loss: 0.6122 - val_accuracy: 0.8432 - lr: 0.0010
# Epoch 28/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6386 - accuracy: 0.8314 - val_loss: 0.6647 - val_accuracy: 0.8290 - lr: 0.0010
# Epoch 29/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6304 - accuracy: 0.8332 - val_loss: 0.6642 - val_accuracy: 0.8265 - lr: 0.0010
# Epoch 30/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6292 - accuracy: 0.8337 - val_loss: 0.6162 - val_accuracy: 0.8387 - lr: 0.0010
# Epoch 31/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6254 - accuracy: 0.8357 - val_loss: 0.6094 - val_accuracy: 0.8451 - lr: 0.0010
# Epoch 32/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6221 - accuracy: 0.8349 - val_loss: 0.6384 - val_accuracy: 0.8404 - lr: 0.0010
# Epoch 33/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6234 - accuracy: 0.8355 - val_loss: 0.6608 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 34/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6209 - accuracy: 0.8371 - val_loss: 0.6378 - val_accuracy: 0.8387 - lr: 0.0010
# Epoch 35/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6186 - accuracy: 0.8372 - val_loss: 0.6273 - val_accuracy: 0.8446 - lr: 0.0010
# Epoch 36/90
# 781/781 [==============================] - 55s 71ms/step - loss: 0.6202 - accuracy: 0.8371 - val_loss: 0.6313 - val_accuracy: 0.8437 - lr: 0.0010
# Epoch 37/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6157 - accuracy: 0.8382 - val_loss: 0.6064 - val_accuracy: 0.8470 - lr: 0.0010
# Epoch 38/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6087 - accuracy: 0.8410 - val_loss: 0.5776 - val_accuracy: 0.8547 - lr: 0.0010
# Epoch 39/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6097 - accuracy: 0.8412 - val_loss: 0.5876 - val_accuracy: 0.8555 - lr: 0.0010
# Epoch 40/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6116 - accuracy: 0.8410 - val_loss: 0.6210 - val_accuracy: 0.8454 - lr: 0.0010
# Epoch 41/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6057 - accuracy: 0.8430 - val_loss: 0.5847 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 42/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6052 - accuracy: 0.8429 - val_loss: 0.6246 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 43/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6074 - accuracy: 0.8436 - val_loss: 0.5799 - val_accuracy: 0.8573 - lr: 0.0010
# Epoch 44/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6021 - accuracy: 0.8447 - val_loss: 0.6309 - val_accuracy: 0.8407 - lr: 0.0010
# Epoch 45/90
# 781/781 [==============================] - 56s 72ms/step - loss: 0.5089 - accuracy: 0.8737 - val_loss: 0.5093 - val_accuracy: 0.8782 - lr: 5.0000e-04
# Epoch 80/90
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4981 - accuracy: 0.8761 - val_loss: 0.5111 - val_accuracy: 0.8780 - lr: 5.0000e-04
# Epoch 81/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4896 - accuracy: 0.8783 - val_loss: 0.5044 - val_accuracy: 0.8818 - lr: 5.0000e-04
# Epoch 82/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.4893 - accuracy: 0.8774 - val_loss: 0.4868 - val_accuracy: 0.8816 - lr: 5.0000e-04
# Epoch 83/90
# 781/781 [==============================] - 52s 67ms/step - loss: 0.4815 - accuracy: 0.8791 - val_loss: 0.4901 - val_accuracy: 0.8820 - lr: 5.0000e-04
# Epoch 84/90
# 781/781 [==============================] - 52s 66ms/step - loss: 0.4801 - accuracy: 0.8811 - val_loss: 0.5152 - val_accuracy: 0.8766 - lr: 5.0000e-04
# Epoch 85/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4807 - accuracy: 0.8806 - val_loss: 0.4820 - val_accuracy: 0.8843 - lr: 5.0000e-04
# Epoch 86/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4771 - accuracy: 0.8794 - val_loss: 0.5110 - val_accuracy: 0.8714 - lr: 5.0000e-04
# Epoch 87/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4745 - accuracy: 0.8803 - val_loss: 0.5469 - val_accuracy: 0.8633 - lr: 5.0000e-04
# Epoch 88/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4699 - accuracy: 0.8815 - val_loss: 0.4838 - val_accuracy: 0.8837 - lr: 5.0000e-04
# Epoch 89/90
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4644 - accuracy: 0.8829 - val_loss: 0.4859 - val_accuracy: 0.8820 - lr: 5.0000e-04
# Epoch 90/90
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4669 - accuracy: 0.8821 - val_loss: 0.5016 - val_accuracy: 0.8757 - lr: 5.0000e-04
# INFO:tensorflow:Assets written to: model/assets

# %%
from tensorflow import keras

model= keras.models.load_model('model')
scores = model.evaluate(x_test,y_test,batch_size=64,verbose=1)

print('accuracy: '+str(scores[1]*100))
print('loss: '+str(scores[0]))
# Out:
# 157/157 [==============================] - 2s 13ms/step - loss: 0.5016 - accuracy: 0.8757
# accuracy: 87.56999969482422
# loss: 0.5015818476676941

# %%
# !zip -r /content/file.zip /content/model/

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/model/ (stored 0%)
#   adding: content/model/variables/ (stored 0%)
#   adding: content/model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/model/variables/variables.index (deflated 73%)
#   adding: content/model/keras_metadata.pb (deflated 94%)
#   adding: content/model/saved_model.pb (deflated 91%)
#   adding: content/model/assets/ (stored 0%)
